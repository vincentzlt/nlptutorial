# %%
import sys
from collections import defaultdict

# %%
class SGD():
    def __init__(self,f_name, iter_times_training=100):
        labels=[]
        lines=[]
        self.ws={}
        
        # read lines and labels
        for line in open(f_name, "r",encoding="utf-8"):
            label, line_=line.split("\t")
            labels.append(label)
            lines.append(line_)
            
        # init the weights by 0
        for w in set(w for w in line.split() for line in lines):
            self.ws[w]=0
        
        # update the weights
        for iter_ in range(iter_times_training):
            for label, line in zip(labels, lines):
                self.update_weight(line)

# %%
def load_training_data(f_name):
    labels=[]
    lines=[]
    for line in open(f_name, "r",encoding="utf-8"):
        label, line_=line.split("\t")
        labels.append(label)
        lines.append(line_)
    return labels,lines

# %%
training_file_path="../../data/titles-en-train.labeled"

# %%
def train_model(labels, lines iter_times=100):
    for iter_ in iter_times:
        for label, line in zip(labels,lines):

# %%
if __name__=="__main__":
    labels,lines=load_training_data(training_file_path)
    for ind,line in enumerate(lines):
        print("sentence {ind}:".format(ind=ind),labels[ind],line,sep="\t")
# Out:
# sentence 0	1	FUJIWARA no Chikamori ( year of birth and death unknown ) was a samurai and poet who lived at the end of the Heian period .
#
# sentence 1	1	Ryonen ( 1646 - October 29 , 1711 ) was a Buddhist nun of the Obaku Sect who lived from the early Edo period to the mid-Edo period .
#
# sentence 2	-1	A moat settlement is a village surrounded by a moat .
#
# sentence 3	-1	Fushimi Momoyama Athletic Park is located in Momoyama-cho , Kyoto City , Kyoto Prefecture .
#
# sentence 4	1	Iwanohimenomikoto ( year of birth unknown – June , 347 ) was an Empress of the Kofun period .
#
# sentence 5	1	YOSHIMINE no Nagamatsu ( 813 - December 30 , 879 ) was a government official who lived during the Heian period .
#
# sentence 6	1	Hiizu MIYAKE ( November 1848 - March 16 , 1938 ) is a doctor , Dutch scholar , medical scientist , members of the Diet ( the House of Peers &#91; Japan &#93; ) in Japan .
#
# ...
