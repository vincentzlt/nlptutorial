# %%
import sys,pprint,math
from collections import  defaultdict

# %%
class w_pos():
    def __init__(self, f_name):
        self.pos_freq = {1: defaultdict(lambda: 0), 2: defaultdict(lambda: 0)}
        self.w_pos_freq = defaultdict(lambda: 0)

        for line in open(f_name, "r", encoding="UTF-8"):
            line = "<s>_<s> " + line.replace("\n", "") + " </s>_</s>"
            pos_line = []
            for w_pos in line.split(" "):
                w_, pos_ = w_pos.split("_")
                pos_line.append(pos_)
                self.w_pos_freq[w_pos] += 1
            for pos_ in pos_line:
                self.pos_freq[1][pos_] += 1
            for pos_ in zip(pos_line, pos_line[1:]):
                self.pos_freq[2][" ".join(pos_)] += 1

        self.pos_transission_matrice = dict()

        for i in self.pos_freq[1]:
            self.pos_transission_matrice[i] = dict()
            for j in self.pos_freq[1]:
                self.pos_transission_matrice[i][
                    j] = self.calc_HMM_transition_P(j, i)

    def calc_HMM_transition_P(self, y_i, y_prev):
        return self.pos_freq[2][y_prev + " " + y_i] / float(self.pos_freq[1][
            y_prev])

    def calc_HMM_emission_P(self, w, tag):
        lambda_ = 0.91
        vocab_size = 10000000
        P = self.w_pos_freq[w + "_" + tag] / float(self.pos_freq[1][tag])
        return lambda_ * P + (1 - lambda_) / float(vocab_size)

    def calc_POS_viterbi(self, line_str):
        line = line_str.split(" ")
        line.append("</s>")
        line.insert(0, "<s>")
        len_line = len(line)
        best_score = dict()
        best_node = dict()
        n_ = 0
        for w in line:
            best_score[w] = dict()
            best_node[w] = dict()
            if w == "<s>":
                best_score[w][str(n_) + "_<s>"] = 0
                best_node[w][str(n_) + "_<s>"] = None
            elif w == "</s>":
                best_score[w][str(n_) + "_</s>"] = 1000000.0
                best_node[w][str(n_) + "_</s>"] = 0
            else:
                for tag in self.pos_freq[1]:
                    if tag!="<s>" and tag!="</s>":
                        best_score[w][str(n_) + "_" + tag] = 1000000.0
                        best_node[w][str(n_) + "_" + tag] = 0
            n_ += 1
        pprint.pprint(best_score)
        pprint.pprint(best_node)
        n_ = 1
        for w, w_prev in zip(line[1:], line):
            for tag_ in best_score[w]:
                tag = tag_.split("_")[1]
                for tag_prev_ in best_score[w_prev]:
                    tag_prev = tag_prev_.split("_")[1]
                    
                    pos_trans_P = self.calc_HMM_transition_P(tag, tag_prev)
                    pos_emiss_P = self.calc_HMM_emission_P(w, tag)
                    if pos_trans_P==0 and pos_emiss_P==0:
                        _=0
                    elif pos_trans_P==0:
                        _ = -math.log( pos_emiss_P)
                    elif pos_emiss_P==0:
                        _ = -math.log( pos_trans_P)
                    else:
                        _ = -math.log(pos_trans_P) -math.log(pos_emiss_P)
                    if _ < best_score[w][str(n_) + "_" + tag]:
                        best_score[w][str(n_) + "_" + tag] = _
                        best_node[w][str(n_) + "_" + tag]=str(n_-1)+"_"+tag_prev
            n_+=1
        pprint.pprint(best_score)
        pprint.pprint(best_node)
        n_-=1
        tags=[]
        next_node=best_node["</s>"][str(n_)+"_</s>"]
        while next_node!="0_<s>":
            ind,tag=next_node.split("_")
            tags.append(tag)
            
            next_node=best_node[line[int(ind)]][next_node]
        tags.reverse()
        return " ".join(tags)

# %%
temp=w_pos(f_name="./wiki-en-train.norm_pos")

# %%
temp.calc_POS_viterbi(
    "Natural language understanding is sometimes referred as an AI-complete problem because it seems to require extensive knowledge about the outside world and the ability to manipulate it ."
)
# Out:
# {'.': {"28_''": 1000000.0,
#        '28_,': 1000000.0,
#        '28_-LRB-': 1000000.0,
#        '28_-RRB-': 1000000.0,
#        '28_.': 1000000.0,
#        '28_:': 1000000.0,
#        '28_CC': 1000000.0,
#        '28_CD': 1000000.0,
#        '28_DT': 1000000.0,
#        '28_EX': 1000000.0,
#        '28_FW': 1000000.0,
#        '28_IN': 1000000.0,
#        '28_JJ': 1000000.0,
#        '28_JJR': 1000000.0,
#        '28_JJS': 1000000.0,
#        '28_LS': 1000000.0,
#        '28_MD': 1000000.0,
#        '28_NN': 1000000.0,
#        '28_NNP': 1000000.0,
#        '28_NNPS': 1000000.0,
#        '28_NNS': 1000000.0,
#        '28_PDT': 1000000.0,
#        '28_POS': 1000000.0,
#        '28_PRP': 1000000.0,
#        '28_PRP$': 1000000.0,
#        '28_RB': 1000000.0,
#        '28_RBR': 1000000.0,
#        '28_RBS': 1000000.0,
#        '28_RP': 1000000.0,
#        '28_TO': 1000000.0,
#        '28_UH': 1000000.0,
#        '28_VB': 1000000.0,
#        '28_VBD': 1000000.0,
#        '28_VBG': 1000000.0,
#        '28_VBN': 1000000.0,
#        '28_VBP': 1000000.0,
#        '28_VBZ': 1000000.0,
#        '28_WDT': 1000000.0,
#        '28_WP': 1000000.0,
#        '28_WP$': 1000000.0,
#        '28_WRB': 1000000.0,
#        '28_``': 1000000.0},
#  '</s>': {'29_</s>': 1000000.0},
#  '<s>': {'0_<s>': 0},
#  'AI-complete': {"9_''": 1000000.0,
#                  '9_,': 1000000.0,
#                  '9_-LRB-': 1000000.0,
#                  '9_-RRB-': 1000000.0,
#                  '9_.': 1000000.0,
#                  '9_:': 1000000.0,
#                  '9_CC': 1000000.0,
#                  '9_CD': 1000000.0,
#                  '9_DT': 1000000.0,
#                  '9_EX': 1000000.0,
#                  '9_FW': 1000000.0,
#                  '9_IN': 1000000.0,
#                  '9_JJ': 1000000.0,
#                  '9_JJR': 1000000.0,
#                  '9_JJS': 1000000.0,
#                  '9_LS': 1000000.0,
#                  '9_MD': 1000000.0,
#                  '9_NN': 1000000.0,
#                  '9_NNP': 1000000.0,
#                  '9_NNPS': 1000000.0,
#                  '9_NNS': 1000000.0,
#                  '9_PDT': 1000000.0,
#                  '9_POS': 1000000.0,
#                  '9_PRP': 1000000.0,
#                  '9_PRP$': 1000000.0,
#                  '9_RB': 1000000.0,
#                  '9_RBR': 1000000.0,
#                  '9_RBS': 1000000.0,
#                  '9_RP': 1000000.0,
#                  '9_TO': 1000000.0,
#                  '9_UH': 1000000.0,
#                  '9_VB': 1000000.0,
#                  '9_VBD': 1000000.0,
#                  '9_VBG': 1000000.0,
#                  '9_VBN': 1000000.0,
#                  '9_VBP': 1000000.0,
#                  '9_VBZ': 1000000.0,
#                  '9_WDT': 1000000.0,
#                  '9_WP': 1000000.0,
#                  '9_WP$': 1000000.0,
#                  '9_WRB': 1000000.0,
#                  '9_``': 1000000.0},
#  'Natural': {"1_''": 1000000.0,
#              '1_,': 1000000.0,
#              '1_-LRB-': 1000000.0,
#              '1_-RRB-': 1000000.0,
#              '1_.': 1000000.0,
#              '1_:': 1000000.0,
#              '1_CC': 1000000.0,
#              '1_CD': 1000000.0,
#              '1_DT': 1000000.0,
#              '1_EX': 1000000.0,
#              '1_FW': 1000000.0,
#              '1_IN': 1000000.0,
#              '1_JJ': 1000000.0,
#              '1_JJR': 1000000.0,
#              '1_JJS': 1000000.0,
#              '1_LS': 1000000.0,
#              '1_MD': 1000000.0,
#              '1_NN': 1000000.0,
#              '1_NNP': 1000000.0,
#              '1_NNPS': 1000000.0,
#              '1_NNS': 1000000.0,
#              '1_PDT': 1000000.0,
#              '1_POS': 1000000.0,
#              '1_PRP': 1000000.0,
#              '1_PRP$': 1000000.0,
#              '1_RB': 1000000.0,
#              '1_RBR': 1000000.0,
#              '1_RBS': 1000000.0,
#              '1_RP': 1000000.0,
#              '1_TO': 1000000.0,
#              '1_UH': 1000000.0,
#              '1_VB': 1000000.0,
#              '1_VBD': 1000000.0,
#              '1_VBG': 1000000.0,
#              '1_VBN': 1000000.0,
#              '1_VBP': 1000000.0,
#              '1_VBZ': 1000000.0,
#              '1_WDT': 1000000.0,
#              '1_WP': 1000000.0,
#              '1_WP$': 1000000.0,
#              '1_WRB': 1000000.0,
#              '1_``': 1000000.0},
#  'ability': {"24_''": 1000000.0,
#              '24_,': 1000000.0,
#              '24_-LRB-': 1000000.0,
#              '24_-RRB-': 1000000.0,
#              '24_.': 1000000.0,
#              '24_:': 1000000.0,
#              '24_CC': 1000000.0,
#              '24_CD': 1000000.0,
#              '24_DT': 1000000.0,
#              '24_EX': 1000000.0,
#              '24_FW': 1000000.0,
#              '24_IN': 1000000.0,
#              '24_JJ': 1000000.0,
#              '24_JJR': 1000000.0,
#              '24_JJS': 1000000.0,
#              '24_LS': 1000000.0,
#              '24_MD': 1000000.0,
#              '24_NN': 1000000.0,
#              '24_NNP': 1000000.0,
#              '24_NNPS': 1000000.0,
#              '24_NNS': 1000000.0,
#              '24_PDT': 1000000.0,
#              '24_POS': 1000000.0,
#              '24_PRP': 1000000.0,
#              '24_PRP$': 1000000.0,
#              '24_RB': 1000000.0,
#              '24_RBR': 1000000.0,
#              '24_RBS': 1000000.0,
#              '24_RP': 1000000.0,
#              '24_TO': 1000000.0,
#              '24_UH': 1000000.0,
#              '24_VB': 1000000.0,
#              '24_VBD': 1000000.0,
#              '24_VBG': 1000000.0,
#              '24_VBN': 1000000.0,
#              '24_VBP': 1000000.0,
#              '24_VBZ': 1000000.0,
#              '24_WDT': 1000000.0,
#              '24_WP': 1000000.0,
#              '24_WP$': 1000000.0,
#              '24_WRB': 1000000.0,
#              '24_``': 1000000.0},
#  'about': {"18_''": 1000000.0,
#            '18_,': 1000000.0,
#            '18_-LRB-': 1000000.0,
#            '18_-RRB-': 1000000.0,
#            '18_.': 1000000.0,
#            '18_:': 1000000.0,
#            '18_CC': 1000000.0,
#            '18_CD': 1000000.0,
#            '18_DT': 1000000.0,
#            '18_EX': 1000000.0,
#            '18_FW': 1000000.0,
#            '18_IN': 1000000.0,
#            '18_JJ': 1000000.0,
#            '18_JJR': 1000000.0,
#            '18_JJS': 1000000.0,
#            '18_LS': 1000000.0,
#            '18_MD': 1000000.0,
#            '18_NN': 1000000.0,
#            '18_NNP': 1000000.0,
#            '18_NNPS': 1000000.0,
#            '18_NNS': 1000000.0,
#            '18_PDT': 1000000.0,
#            '18_POS': 1000000.0,
#            '18_PRP': 1000000.0,
#            '18_PRP$': 1000000.0,
#            '18_RB': 1000000.0,
#            '18_RBR': 1000000.0,
#            '18_RBS': 1000000.0,
#            '18_RP': 1000000.0,
#            '18_TO': 1000000.0,
#            '18_UH': 1000000.0,
#            '18_VB': 1000000.0,
#            '18_VBD': 1000000.0,
#            '18_VBG': 1000000.0,
#            '18_VBN': 1000000.0,
#            '18_VBP': 1000000.0,
#            '18_VBZ': 1000000.0,
#            '18_WDT': 1000000.0,
#            '18_WP': 1000000.0,
#            '18_WP$': 1000000.0,
#            '18_WRB': 1000000.0,
#            '18_``': 1000000.0},
#  'an': {"8_''": 1000000.0,
#         '8_,': 1000000.0,
#         '8_-LRB-': 1000000.0,
#         '8_-RRB-': 1000000.0,
#         '8_.': 1000000.0,
#         '8_:': 1000000.0,
#         '8_CC': 1000000.0,
#         '8_CD': 1000000.0,
#         '8_DT': 1000000.0,
#         '8_EX': 1000000.0,
#         '8_FW': 1000000.0,
#         '8_IN': 1000000.0,
#         '8_JJ': 1000000.0,
#         '8_JJR': 1000000.0,
#         '8_JJS': 1000000.0,
#         '8_LS': 1000000.0,
#         '8_MD': 1000000.0,
#         '8_NN': 1000000.0,
#         '8_NNP': 1000000.0,
#         '8_NNPS': 1000000.0,
#         '8_NNS': 1000000.0,
#         '8_PDT': 1000000.0,
#         '8_POS': 1000000.0,
#         '8_PRP': 1000000.0,
#         '8_PRP$': 1000000.0,
#         '8_RB': 1000000.0,
#         '8_RBR': 1000000.0,
#         '8_RBS': 1000000.0,
#         '8_RP': 1000000.0,
#         '8_TO': 1000000.0,
#         '8_UH': 1000000.0,
#         '8_VB': 1000000.0,
#         '8_VBD': 1000000.0,
#         '8_VBG': 1000000.0,
#         '8_VBN': 1000000.0,
#         '8_VBP': 1000000.0,
#         '8_VBZ': 1000000.0,
#         '8_WDT': 1000000.0,
#         '8_WP': 1000000.0,
#         '8_WP$': 1000000.0,
#         '8_WRB': 1000000.0,
#         '8_``': 1000000.0},
#  'and': {"22_''": 1000000.0,
#          '22_,': 1000000.0,
#          '22_-LRB-': 1000000.0,
#          '22_-RRB-': 1000000.0,
#          '22_.': 1000000.0,
#          '22_:': 1000000.0,
#          '22_CC': 1000000.0,
#          '22_CD': 1000000.0,
#          '22_DT': 1000000.0,
#          '22_EX': 1000000.0,
#          '22_FW': 1000000.0,
#          '22_IN': 1000000.0,
#          '22_JJ': 1000000.0,
#          '22_JJR': 1000000.0,
#          '22_JJS': 1000000.0,
#          '22_LS': 1000000.0,
#          '22_MD': 1000000.0,
#          '22_NN': 1000000.0,
#          '22_NNP': 1000000.0,
#          '22_NNPS': 1000000.0,
#          '22_NNS': 1000000.0,
#          '22_PDT': 1000000.0,
#          '22_POS': 1000000.0,
#          '22_PRP': 1000000.0,
#          '22_PRP$': 1000000.0,
#          '22_RB': 1000000.0,
#          '22_RBR': 1000000.0,
#          '22_RBS': 1000000.0,
#          '22_RP': 1000000.0,
#          '22_TO': 1000000.0,
#          '22_UH': 1000000.0,
#          '22_VB': 1000000.0,
#          '22_VBD': 1000000.0,
#          '22_VBG': 1000000.0,
#          '22_VBN': 1000000.0,
#          '22_VBP': 1000000.0,
#          '22_VBZ': 1000000.0,
#          '22_WDT': 1000000.0,
#          '22_WP': 1000000.0,
#          '22_WP$': 1000000.0,
#          '22_WRB': 1000000.0,
#          '22_``': 1000000.0},
#  'as': {"7_''": 1000000.0,
#         '7_,': 1000000.0,
#         '7_-LRB-': 1000000.0,
#         '7_-RRB-': 1000000.0,
#         '7_.': 1000000.0,
#         '7_:': 1000000.0,
#         '7_CC': 1000000.0,
#         '7_CD': 1000000.0,
#         '7_DT': 1000000.0,
#         '7_EX': 1000000.0,
#         '7_FW': 1000000.0,
#         '7_IN': 1000000.0,
#         '7_JJ': 1000000.0,
#         '7_JJR': 1000000.0,
#         '7_JJS': 1000000.0,
#         '7_LS': 1000000.0,
#         '7_MD': 1000000.0,
#         '7_NN': 1000000.0,
#         '7_NNP': 1000000.0,
#         '7_NNPS': 1000000.0,
#         '7_NNS': 1000000.0,
#         '7_PDT': 1000000.0,
#         '7_POS': 1000000.0,
#         '7_PRP': 1000000.0,
#         '7_PRP$': 1000000.0,
#         '7_RB': 1000000.0,
#         '7_RBR': 1000000.0,
#         '7_RBS': 1000000.0,
#         '7_RP': 1000000.0,
#         '7_TO': 1000000.0,
#         '7_UH': 1000000.0,
#         '7_VB': 1000000.0,
#         '7_VBD': 1000000.0,
#         '7_VBG': 1000000.0,
#         '7_VBN': 1000000.0,
#         '7_VBP': 1000000.0,
#         '7_VBZ': 1000000.0,
#         '7_WDT': 1000000.0,
#         '7_WP': 1000000.0,
#         '7_WP$': 1000000.0,
#         '7_WRB': 1000000.0,
#         '7_``': 1000000.0},
#  'because': {"11_''": 1000000.0,
#              '11_,': 1000000.0,
#              '11_-LRB-': 1000000.0,
#              '11_-RRB-': 1000000.0,
#              '11_.': 1000000.0,
#              '11_:': 1000000.0,
#              '11_CC': 1000000.0,
#              '11_CD': 1000000.0,
#              '11_DT': 1000000.0,
#              '11_EX': 1000000.0,
#              '11_FW': 1000000.0,
#              '11_IN': 1000000.0,
#              '11_JJ': 1000000.0,
#              '11_JJR': 1000000.0,
#              '11_JJS': 1000000.0,
#              '11_LS': 1000000.0,
#              '11_MD': 1000000.0,
#              '11_NN': 1000000.0,
#              '11_NNP': 1000000.0,
#              '11_NNPS': 1000000.0,
#              '11_NNS': 1000000.0,
#              '11_PDT': 1000000.0,
#              '11_POS': 1000000.0,
#              '11_PRP': 1000000.0,
#              '11_PRP$': 1000000.0,
#              '11_RB': 1000000.0,
#              '11_RBR': 1000000.0,
#              '11_RBS': 1000000.0,
#              '11_RP': 1000000.0,
#              '11_TO': 1000000.0,
#              '11_UH': 1000000.0,
#              '11_VB': 1000000.0,
#              '11_VBD': 1000000.0,
#              '11_VBG': 1000000.0,
#              '11_VBN': 1000000.0,
#              '11_VBP': 1000000.0,
#              '11_VBZ': 1000000.0,
#              '11_WDT': 1000000.0,
#              '11_WP': 1000000.0,
#              '11_WP$': 1000000.0,
#              '11_WRB': 1000000.0,
#              '11_``': 1000000.0},
#  'extensive': {"16_''": 1000000.0,
#                '16_,': 1000000.0,
#                '16_-LRB-': 1000000.0,
#                '16_-RRB-': 1000000.0,
#                '16_.': 1000000.0,
#                '16_:': 1000000.0,
#                '16_CC': 1000000.0,
#                '16_CD': 1000000.0,
#                '16_DT': 1000000.0,
#                '16_EX': 1000000.0,
#                '16_FW': 1000000.0,
#                '16_IN': 1000000.0,
#                '16_JJ': 1000000.0,
#                '16_JJR': 1000000.0,
#                '16_JJS': 1000000.0,
#                '16_LS': 1000000.0,
#                '16_MD': 1000000.0,
#                '16_NN': 1000000.0,
#                '16_NNP': 1000000.0,
#                '16_NNPS': 1000000.0,
#                '16_NNS': 1000000.0,
#                '16_PDT': 1000000.0,
#                '16_POS': 1000000.0,
#                '16_PRP': 1000000.0,
#                '16_PRP$': 1000000.0,
#                '16_RB': 1000000.0,
#                '16_RBR': 1000000.0,
#                '16_RBS': 1000000.0,
#                '16_RP': 1000000.0,
#                '16_TO': 1000000.0,
#                '16_UH': 1000000.0,
#                '16_VB': 1000000.0,
#                '16_VBD': 1000000.0,
#                '16_VBG': 1000000.0,
#                '16_VBN': 1000000.0,
#                '16_VBP': 1000000.0,
#                '16_VBZ': 1000000.0,
#                '16_WDT': 1000000.0,
#                '16_WP': 1000000.0,
#                '16_WP$': 1000000.0,
#                '16_WRB': 1000000.0,
#                '16_``': 1000000.0},
#  'is': {"4_''": 1000000.0,
#         '4_,': 1000000.0,
#         '4_-LRB-': 1000000.0,
#         '4_-RRB-': 1000000.0,
#         '4_.': 1000000.0,
#         '4_:': 1000000.0,
#         '4_CC': 1000000.0,
#         '4_CD': 1000000.0,
#         '4_DT': 1000000.0,
#         '4_EX': 1000000.0,
#         '4_FW': 1000000.0,
#         '4_IN': 1000000.0,
#         '4_JJ': 1000000.0,
#         '4_JJR': 1000000.0,
#         '4_JJS': 1000000.0,
#         '4_LS': 1000000.0,
#         '4_MD': 1000000.0,
#         '4_NN': 1000000.0,
#         '4_NNP': 1000000.0,
#         '4_NNPS': 1000000.0,
#         '4_NNS': 1000000.0,
#         '4_PDT': 1000000.0,
#         '4_POS': 1000000.0,
#         '4_PRP': 1000000.0,
#         '4_PRP$': 1000000.0,
#         '4_RB': 1000000.0,
#         '4_RBR': 1000000.0,
#         '4_RBS': 1000000.0,
#         '4_RP': 1000000.0,
#         '4_TO': 1000000.0,
#         '4_UH': 1000000.0,
#         '4_VB': 1000000.0,
#         '4_VBD': 1000000.0,
#         '4_VBG': 1000000.0,
#         '4_VBN': 1000000.0,
#         '4_VBP': 1000000.0,
#         '4_VBZ': 1000000.0,
#         '4_WDT': 1000000.0,
#         '4_WP': 1000000.0,
#         '4_WP$': 1000000.0,
#         '4_WRB': 1000000.0,
#         '4_``': 1000000.0},
#  'it': {"27_''": 1000000.0,
#         '27_,': 1000000.0,
#         '27_-LRB-': 1000000.0,
#         '27_-RRB-': 1000000.0,
#         '27_.': 1000000.0,
#         '27_:': 1000000.0,
#         '27_CC': 1000000.0,
#         '27_CD': 1000000.0,
#         '27_DT': 1000000.0,
#         '27_EX': 1000000.0,
#         '27_FW': 1000000.0,
#         '27_IN': 1000000.0,
#         '27_JJ': 1000000.0,
#         '27_JJR': 1000000.0,
#         '27_JJS': 1000000.0,
#         '27_LS': 1000000.0,
#         '27_MD': 1000000.0,
#         '27_NN': 1000000.0,
#         '27_NNP': 1000000.0,
#         '27_NNPS': 1000000.0,
#         '27_NNS': 1000000.0,
#         '27_PDT': 1000000.0,
#         '27_POS': 1000000.0,
#         '27_PRP': 1000000.0,
#         '27_PRP$': 1000000.0,
#         '27_RB': 1000000.0,
#         '27_RBR': 1000000.0,
#         '27_RBS': 1000000.0,
#         '27_RP': 1000000.0,
#         '27_TO': 1000000.0,
#         '27_UH': 1000000.0,
#         '27_VB': 1000000.0,
#         '27_VBD': 1000000.0,
#         '27_VBG': 1000000.0,
#         '27_VBN': 1000000.0,
#         '27_VBP': 1000000.0,
#         '27_VBZ': 1000000.0,
#         '27_WDT': 1000000.0,
#         '27_WP': 1000000.0,
#         '27_WP$': 1000000.0,
#         '27_WRB': 1000000.0,
#         '27_``': 1000000.0},
#  'knowledge': {"17_''": 1000000.0,
#                '17_,': 1000000.0,
#                '17_-LRB-': 1000000.0,
#                '17_-RRB-': 1000000.0,
#                '17_.': 1000000.0,
#                '17_:': 1000000.0,
#                '17_CC': 1000000.0,
#                '17_CD': 1000000.0,
#                '17_DT': 1000000.0,
#                '17_EX': 1000000.0,
#                '17_FW': 1000000.0,
#                '17_IN': 1000000.0,
#                '17_JJ': 1000000.0,
#                '17_JJR': 1000000.0,
#                '17_JJS': 1000000.0,
#                '17_LS': 1000000.0,
#                '17_MD': 1000000.0,
#                '17_NN': 1000000.0,
#                '17_NNP': 1000000.0,
#                '17_NNPS': 1000000.0,
#                '17_NNS': 1000000.0,
#                '17_PDT': 1000000.0,
#                '17_POS': 1000000.0,
#                '17_PRP': 1000000.0,
#                '17_PRP$': 1000000.0,
#                '17_RB': 1000000.0,
#                '17_RBR': 1000000.0,
#                '17_RBS': 1000000.0,
#                '17_RP': 1000000.0,
#                '17_TO': 1000000.0,
#                '17_UH': 1000000.0,
#                '17_VB': 1000000.0,
#                '17_VBD': 1000000.0,
#                '17_VBG': 1000000.0,
#                '17_VBN': 1000000.0,
#                '17_VBP': 1000000.0,
#                '17_VBZ': 1000000.0,
#                '17_WDT': 1000000.0,
#                '17_WP': 1000000.0,
#                '17_WP$': 1000000.0,
#                '17_WRB': 1000000.0,
#                '17_``': 1000000.0},
#  'language': {"2_''": 1000000.0,
#               '2_,': 1000000.0,
#               '2_-LRB-': 1000000.0,
#               '2_-RRB-': 1000000.0,
#               '2_.': 1000000.0,
#               '2_:': 1000000.0,
#               '2_CC': 1000000.0,
#               '2_CD': 1000000.0,
#               '2_DT': 1000000.0,
#               '2_EX': 1000000.0,
#               '2_FW': 1000000.0,
#               '2_IN': 1000000.0,
#               '2_JJ': 1000000.0,
#               '2_JJR': 1000000.0,
#               '2_JJS': 1000000.0,
#               '2_LS': 1000000.0,
#               '2_MD': 1000000.0,
#               '2_NN': 1000000.0,
#               '2_NNP': 1000000.0,
#               '2_NNPS': 1000000.0,
#               '2_NNS': 1000000.0,
#               '2_PDT': 1000000.0,
#               '2_POS': 1000000.0,
#               '2_PRP': 1000000.0,
#               '2_PRP$': 1000000.0,
#               '2_RB': 1000000.0,
#               '2_RBR': 1000000.0,
#               '2_RBS': 1000000.0,
#               '2_RP': 1000000.0,
#               '2_TO': 1000000.0,
#               '2_UH': 1000000.0,
#               '2_VB': 1000000.0,
#               '2_VBD': 1000000.0,
#               '2_VBG': 1000000.0,
#               '2_VBN': 1000000.0,
#               '2_VBP': 1000000.0,
#               '2_VBZ': 1000000.0,
#               '2_WDT': 1000000.0,
#               '2_WP': 1000000.0,
#               '2_WP$': 1000000.0,
#               '2_WRB': 1000000.0,
#               '2_``': 1000000.0},
#  'manipulate': {"26_''": 1000000.0,
#                 '26_,': 1000000.0,
#                 '26_-LRB-': 1000000.0,
#                 '26_-RRB-': 1000000.0,
#                 '26_.': 1000000.0,
#                 '26_:': 1000000.0,
#                 '26_CC': 1000000.0,
#                 '26_CD': 1000000.0,
#                 '26_DT': 1000000.0,
#                 '26_EX': 1000000.0,
#                 '26_FW': 1000000.0,
#                 '26_IN': 1000000.0,
#                 '26_JJ': 1000000.0,
#                 '26_JJR': 1000000.0,
#                 '26_JJS': 1000000.0,
#                 '26_LS': 1000000.0,
#                 '26_MD': 1000000.0,
#                 '26_NN': 1000000.0,
#                 '26_NNP': 1000000.0,
#                 '26_NNPS': 1000000.0,
#                 '26_NNS': 1000000.0,
#                 '26_PDT': 1000000.0,
#                 '26_POS': 1000000.0,
#                 '26_PRP': 1000000.0,
#                 '26_PRP$': 1000000.0,
#                 '26_RB': 1000000.0,
#                 '26_RBR': 1000000.0,
#                 '26_RBS': 1000000.0,
#                 '26_RP': 1000000.0,
#                 '26_TO': 1000000.0,
#                 '26_UH': 1000000.0,
#                 '26_VB': 1000000.0,
#                 '26_VBD': 1000000.0,
#                 '26_VBG': 1000000.0,
#                 '26_VBN': 1000000.0,
#                 '26_VBP': 1000000.0,
#                 '26_VBZ': 1000000.0,
#                 '26_WDT': 1000000.0,
#                 '26_WP': 1000000.0,
#                 '26_WP$': 1000000.0,
#                 '26_WRB': 1000000.0,
#                 '26_``': 1000000.0},
#  'outside': {"20_''": 1000000.0,
#              '20_,': 1000000.0,
#              '20_-LRB-': 1000000.0,
#              '20_-RRB-': 1000000.0,
#              '20_.': 1000000.0,
#              '20_:': 1000000.0,
#              '20_CC': 1000000.0,
#              '20_CD': 1000000.0,
#              '20_DT': 1000000.0,
#              '20_EX': 1000000.0,
#              '20_FW': 1000000.0,
#              '20_IN': 1000000.0,
#              '20_JJ': 1000000.0,
#              '20_JJR': 1000000.0,
#              '20_JJS': 1000000.0,
#              '20_LS': 1000000.0,
#              '20_MD': 1000000.0,
#              '20_NN': 1000000.0,
#              '20_NNP': 1000000.0,
#              '20_NNPS': 1000000.0,
#              '20_NNS': 1000000.0,
#              '20_PDT': 1000000.0,
#              '20_POS': 1000000.0,
#              '20_PRP': 1000000.0,
#              '20_PRP$': 1000000.0,
#              '20_RB': 1000000.0,
#              '20_RBR': 1000000.0,
#              '20_RBS': 1000000.0,
#              '20_RP': 1000000.0,
#              '20_TO': 1000000.0,
#              '20_UH': 1000000.0,
#              '20_VB': 1000000.0,
#              '20_VBD': 1000000.0,
#              '20_VBG': 1000000.0,
#              '20_VBN': 1000000.0,
#              '20_VBP': 1000000.0,
#              '20_VBZ': 1000000.0,
#              '20_WDT': 1000000.0,
#              '20_WP': 1000000.0,
#              '20_WP$': 1000000.0,
#              '20_WRB': 1000000.0,
#              '20_``': 1000000.0},
#  'problem': {"10_''": 1000000.0,
#              '10_,': 1000000.0,
#              '10_-LRB-': 1000000.0,
#              '10_-RRB-': 1000000.0,
#              '10_.': 1000000.0,
#              '10_:': 1000000.0,
#              '10_CC': 1000000.0,
#              '10_CD': 1000000.0,
#              '10_DT': 1000000.0,
#              '10_EX': 1000000.0,
#              '10_FW': 1000000.0,
#              '10_IN': 1000000.0,
#              '10_JJ': 1000000.0,
#              '10_JJR': 1000000.0,
#              '10_JJS': 1000000.0,
#              '10_LS': 1000000.0,
#              '10_MD': 1000000.0,
#              '10_NN': 1000000.0,
#              '10_NNP': 1000000.0,
#              '10_NNPS': 1000000.0,
#              '10_NNS': 1000000.0,
#              '10_PDT': 1000000.0,
#              '10_POS': 1000000.0,
#              '10_PRP': 1000000.0,
#              '10_PRP$': 1000000.0,
#              '10_RB': 1000000.0,
#              '10_RBR': 1000000.0,
#              '10_RBS': 1000000.0,
#              '10_RP': 1000000.0,
#              '10_TO': 1000000.0,
#              '10_UH': 1000000.0,
#              '10_VB': 1000000.0,
#              '10_VBD': 1000000.0,
#              '10_VBG': 1000000.0,
#              '10_VBN': 1000000.0,
#              '10_VBP': 1000000.0,
#              '10_VBZ': 1000000.0,
#              '10_WDT': 1000000.0,
#              '10_WP': 1000000.0,
#              '10_WP$': 1000000.0,
#              '10_WRB': 1000000.0,
#              '10_``': 1000000.0},
#  'referred': {"6_''": 1000000.0,
#               '6_,': 1000000.0,
#               '6_-LRB-': 1000000.0,
#               '6_-RRB-': 1000000.0,
#               '6_.': 1000000.0,
#               '6_:': 1000000.0,
#               '6_CC': 1000000.0,
#               '6_CD': 1000000.0,
#               '6_DT': 1000000.0,
#               '6_EX': 1000000.0,
#               '6_FW': 1000000.0,
#               '6_IN': 1000000.0,
#               '6_JJ': 1000000.0,
#               '6_JJR': 1000000.0,
#               '6_JJS': 1000000.0,
#               '6_LS': 1000000.0,
#               '6_MD': 1000000.0,
#               '6_NN': 1000000.0,
#               '6_NNP': 1000000.0,
#               '6_NNPS': 1000000.0,
#               '6_NNS': 1000000.0,
#               '6_PDT': 1000000.0,
#               '6_POS': 1000000.0,
#               '6_PRP': 1000000.0,
#               '6_PRP$': 1000000.0,
#               '6_RB': 1000000.0,
#               '6_RBR': 1000000.0,
#               '6_RBS': 1000000.0,
#               '6_RP': 1000000.0,
#               '6_TO': 1000000.0,
#               '6_UH': 1000000.0,
#               '6_VB': 1000000.0,
#               '6_VBD': 1000000.0,
#               '6_VBG': 1000000.0,
#               '6_VBN': 1000000.0,
#               '6_VBP': 1000000.0,
#               '6_VBZ': 1000000.0,
#               '6_WDT': 1000000.0,
#               '6_WP': 1000000.0,
#               '6_WP$': 1000000.0,
#               '6_WRB': 1000000.0,
#               '6_``': 1000000.0},
#  'require': {"15_''": 1000000.0,
#              '15_,': 1000000.0,
#              '15_-LRB-': 1000000.0,
#              '15_-RRB-': 1000000.0,
#              '15_.': 1000000.0,
#              '15_:': 1000000.0,
#              '15_CC': 1000000.0,
#              '15_CD': 1000000.0,
#              '15_DT': 1000000.0,
#              '15_EX': 1000000.0,
#              '15_FW': 1000000.0,
#              '15_IN': 1000000.0,
#              '15_JJ': 1000000.0,
#              '15_JJR': 1000000.0,
#              '15_JJS': 1000000.0,
#              '15_LS': 1000000.0,
#              '15_MD': 1000000.0,
#              '15_NN': 1000000.0,
#              '15_NNP': 1000000.0,
#              '15_NNPS': 1000000.0,
#              '15_NNS': 1000000.0,
#              '15_PDT': 1000000.0,
#              '15_POS': 1000000.0,
#              '15_PRP': 1000000.0,
#              '15_PRP$': 1000000.0,
#              '15_RB': 1000000.0,
#              '15_RBR': 1000000.0,
#              '15_RBS': 1000000.0,
#              '15_RP': 1000000.0,
#              '15_TO': 1000000.0,
#              '15_UH': 1000000.0,
#              '15_VB': 1000000.0,
#              '15_VBD': 1000000.0,
#              '15_VBG': 1000000.0,
#              '15_VBN': 1000000.0,
#              '15_VBP': 1000000.0,
#              '15_VBZ': 1000000.0,
#              '15_WDT': 1000000.0,
#              '15_WP': 1000000.0,
#              '15_WP$': 1000000.0,
#              '15_WRB': 1000000.0,
#              '15_``': 1000000.0},
#  'seems': {"13_''": 1000000.0,
#            '13_,': 1000000.0,
#            '13_-LRB-': 1000000.0,
#            '13_-RRB-': 1000000.0,
#            '13_.': 1000000.0,
#            '13_:': 1000000.0,
#            '13_CC': 1000000.0,
#            '13_CD': 1000000.0,
#            '13_DT': 1000000.0,
#            '13_EX': 1000000.0,
#            '13_FW': 1000000.0,
#            '13_IN': 1000000.0,
#            '13_JJ': 1000000.0,
#            '13_JJR': 1000000.0,
#            '13_JJS': 1000000.0,
#            '13_LS': 1000000.0,
#            '13_MD': 1000000.0,
#            '13_NN': 1000000.0,
#            '13_NNP': 1000000.0,
#            '13_NNPS': 1000000.0,
#            '13_NNS': 1000000.0,
#            '13_PDT': 1000000.0,
#            '13_POS': 1000000.0,
#            '13_PRP': 1000000.0,
#            '13_PRP$': 1000000.0,
#            '13_RB': 1000000.0,
#            '13_RBR': 1000000.0,
#            '13_RBS': 1000000.0,
#            '13_RP': 1000000.0,
#            '13_TO': 1000000.0,
#            '13_UH': 1000000.0,
#            '13_VB': 1000000.0,
#            '13_VBD': 1000000.0,
#            '13_VBG': 1000000.0,
#            '13_VBN': 1000000.0,
#            '13_VBP': 1000000.0,
#            '13_VBZ': 1000000.0,
#            '13_WDT': 1000000.0,
#            '13_WP': 1000000.0,
#            '13_WP$': 1000000.0,
#            '13_WRB': 1000000.0,
#            '13_``': 1000000.0},
#  'sometimes': {"5_''": 1000000.0,
#                '5_,': 1000000.0,
#                '5_-LRB-': 1000000.0,
#                '5_-RRB-': 1000000.0,
#                '5_.': 1000000.0,
#                '5_:': 1000000.0,
#                '5_CC': 1000000.0,
#                '5_CD': 1000000.0,
#                '5_DT': 1000000.0,
#                '5_EX': 1000000.0,
#                '5_FW': 1000000.0,
#                '5_IN': 1000000.0,
#                '5_JJ': 1000000.0,
#                '5_JJR': 1000000.0,
#                '5_JJS': 1000000.0,
#                '5_LS': 1000000.0,
#                '5_MD': 1000000.0,
#                '5_NN': 1000000.0,
#                '5_NNP': 1000000.0,
#                '5_NNPS': 1000000.0,
#                '5_NNS': 1000000.0,
#                '5_PDT': 1000000.0,
#                '5_POS': 1000000.0,
#                '5_PRP': 1000000.0,
#                '5_PRP$': 1000000.0,
#                '5_RB': 1000000.0,
#                '5_RBR': 1000000.0,
#                '5_RBS': 1000000.0,
#                '5_RP': 1000000.0,
#                '5_TO': 1000000.0,
#                '5_UH': 1000000.0,
#                '5_VB': 1000000.0,
#                '5_VBD': 1000000.0,
#                '5_VBG': 1000000.0,
#                '5_VBN': 1000000.0,
#                '5_VBP': 1000000.0,
#                '5_VBZ': 1000000.0,
#                '5_WDT': 1000000.0,
#                '5_WP': 1000000.0,
#                '5_WP$': 1000000.0,
#                '5_WRB': 1000000.0,
#                '5_``': 1000000.0},
#  'the': {"23_''": 1000000.0,
#          '23_,': 1000000.0,
#          '23_-LRB-': 1000000.0,
#          '23_-RRB-': 1000000.0,
#          '23_.': 1000000.0,
#          '23_:': 1000000.0,
#          '23_CC': 1000000.0,
#          '23_CD': 1000000.0,
#          '23_DT': 1000000.0,
#          '23_EX': 1000000.0,
#          '23_FW': 1000000.0,
#          '23_IN': 1000000.0,
#          '23_JJ': 1000000.0,
#          '23_JJR': 1000000.0,
#          '23_JJS': 1000000.0,
#          '23_LS': 1000000.0,
#          '23_MD': 1000000.0,
#          '23_NN': 1000000.0,
#          '23_NNP': 1000000.0,
#          '23_NNPS': 1000000.0,
#          '23_NNS': 1000000.0,
#          '23_PDT': 1000000.0,
#          '23_POS': 1000000.0,
#          '23_PRP': 1000000.0,
#          '23_PRP$': 1000000.0,
#          '23_RB': 1000000.0,
#          '23_RBR': 1000000.0,
#          '23_RBS': 1000000.0,
#          '23_RP': 1000000.0,
#          '23_TO': 1000000.0,
#          '23_UH': 1000000.0,
#          '23_VB': 1000000.0,
#          '23_VBD': 1000000.0,
#          '23_VBG': 1000000.0,
#          '23_VBN': 1000000.0,
#          '23_VBP': 1000000.0,
#          '23_VBZ': 1000000.0,
#          '23_WDT': 1000000.0,
#          '23_WP': 1000000.0,
#          '23_WP$': 1000000.0,
#          '23_WRB': 1000000.0,
#          '23_``': 1000000.0},
#  'to': {"25_''": 1000000.0,
#         '25_,': 1000000.0,
#         '25_-LRB-': 1000000.0,
#         '25_-RRB-': 1000000.0,
#         '25_.': 1000000.0,
#         '25_:': 1000000.0,
#         '25_CC': 1000000.0,
#         '25_CD': 1000000.0,
#         '25_DT': 1000000.0,
#         '25_EX': 1000000.0,
#         '25_FW': 1000000.0,
#         '25_IN': 1000000.0,
#         '25_JJ': 1000000.0,
#         '25_JJR': 1000000.0,
#         '25_JJS': 1000000.0,
#         '25_LS': 1000000.0,
#         '25_MD': 1000000.0,
#         '25_NN': 1000000.0,
#         '25_NNP': 1000000.0,
#         '25_NNPS': 1000000.0,
#         '25_NNS': 1000000.0,
#         '25_PDT': 1000000.0,
#         '25_POS': 1000000.0,
#         '25_PRP': 1000000.0,
#         '25_PRP$': 1000000.0,
#         '25_RB': 1000000.0,
#         '25_RBR': 1000000.0,
#         '25_RBS': 1000000.0,
#         '25_RP': 1000000.0,
#         '25_TO': 1000000.0,
#         '25_UH': 1000000.0,
#         '25_VB': 1000000.0,
#         '25_VBD': 1000000.0,
#         '25_VBG': 1000000.0,
#         '25_VBN': 1000000.0,
#         '25_VBP': 1000000.0,
#         '25_VBZ': 1000000.0,
#         '25_WDT': 1000000.0,
#         '25_WP': 1000000.0,
#         '25_WP$': 1000000.0,
#         '25_WRB': 1000000.0,
#         '25_``': 1000000.0},
#  'understanding': {"3_''": 1000000.0,
#                    '3_,': 1000000.0,
#                    '3_-LRB-': 1000000.0,
#                    '3_-RRB-': 1000000.0,
#                    '3_.': 1000000.0,
#                    '3_:': 1000000.0,
#                    '3_CC': 1000000.0,
#                    '3_CD': 1000000.0,
#                    '3_DT': 1000000.0,
#                    '3_EX': 1000000.0,
#                    '3_FW': 1000000.0,
#                    '3_IN': 1000000.0,
#                    '3_JJ': 1000000.0,
#                    '3_JJR': 1000000.0,
#                    '3_JJS': 1000000.0,
#                    '3_LS': 1000000.0,
#                    '3_MD': 1000000.0,
#                    '3_NN': 1000000.0,
#                    '3_NNP': 1000000.0,
#                    '3_NNPS': 1000000.0,
#                    '3_NNS': 1000000.0,
#                    '3_PDT': 1000000.0,
#                    '3_POS': 1000000.0,
#                    '3_PRP': 1000000.0,
#                    '3_PRP$': 1000000.0,
#                    '3_RB': 1000000.0,
#                    '3_RBR': 1000000.0,
#                    '3_RBS': 1000000.0,
#                    '3_RP': 1000000.0,
#                    '3_TO': 1000000.0,
#                    '3_UH': 1000000.0,
#                    '3_VB': 1000000.0,
#                    '3_VBD': 1000000.0,
#                    '3_VBG': 1000000.0,
#                    '3_VBN': 1000000.0,
#                    '3_VBP': 1000000.0,
#                    '3_VBZ': 1000000.0,
#                    '3_WDT': 1000000.0,
#                    '3_WP': 1000000.0,
#                    '3_WP$': 1000000.0,
#                    '3_WRB': 1000000.0,
#                    '3_``': 1000000.0},
#  'world': {"21_''": 1000000.0,
#            '21_,': 1000000.0,
#            '21_-LRB-': 1000000.0,
#            '21_-RRB-': 1000000.0,
#            '21_.': 1000000.0,
#            '21_:': 1000000.0,
#            '21_CC': 1000000.0,
#            '21_CD': 1000000.0,
#            '21_DT': 1000000.0,
#            '21_EX': 1000000.0,
#            '21_FW': 1000000.0,
#            '21_IN': 1000000.0,
#            '21_JJ': 1000000.0,
#            '21_JJR': 1000000.0,
#            '21_JJS': 1000000.0,
#            '21_LS': 1000000.0,
#            '21_MD': 1000000.0,
#            '21_NN': 1000000.0,
#            '21_NNP': 1000000.0,
#            '21_NNPS': 1000000.0,
#            '21_NNS': 1000000.0,
#            '21_PDT': 1000000.0,
#            '21_POS': 1000000.0,
#            '21_PRP': 1000000.0,
#            '21_PRP$': 1000000.0,
#            '21_RB': 1000000.0,
#            '21_RBR': 1000000.0,
#            '21_RBS': 1000000.0,
#            '21_RP': 1000000.0,
#            '21_TO': 1000000.0,
#            '21_UH': 1000000.0,
#            '21_VB': 1000000.0,
#            '21_VBD': 1000000.0,
#            '21_VBG': 1000000.0,
#            '21_VBN': 1000000.0,
#            '21_VBP': 1000000.0,
#            '21_VBZ': 1000000.0,
#            '21_WDT': 1000000.0,
#            '21_WP': 1000000.0,
#            '21_WP$': 1000000.0,
#            '21_WRB': 1000000.0,
#            '21_``': 1000000.0}}
# {'.': {"28_''": 0,
#        '28_,': 0,
#        '28_-LRB-': 0,
#        '28_-RRB-': 0,
#        '28_.': 0,
#        '28_:': 0,
#        '28_CC': 0,
#        '28_CD': 0,
#        '28_DT': 0,
#        '28_EX': 0,
#        '28_FW': 0,
#        '28_IN': 0,
#        '28_JJ': 0,
#        '28_JJR': 0,
#        '28_JJS': 0,
#        '28_LS': 0,
#        '28_MD': 0,
#        '28_NN': 0,
#        '28_NNP': 0,
#        '28_NNPS': 0,
#        '28_NNS': 0,
#        '28_PDT': 0,
#        '28_POS': 0,
#        '28_PRP': 0,
#        '28_PRP$': 0,
#        '28_RB': 0,
#        '28_RBR': 0,
#        '28_RBS': 0,
#        '28_RP': 0,
#        '28_TO': 0,
#        '28_UH': 0,
#        '28_VB': 0,
#        '28_VBD': 0,
#        '28_VBG': 0,
#        '28_VBN': 0,
#        '28_VBP': 0,
#        '28_VBZ': 0,
#        '28_WDT': 0,
#        '28_WP': 0,
#        '28_WP$': 0,
#        '28_WRB': 0,
#        '28_``': 0},
#  '</s>': {'29_</s>': 0},
#  '<s>': {'0_<s>': None},
#  'AI-complete': {"9_''": 0,
#                  '9_,': 0,
#                  '9_-LRB-': 0,
#                  '9_-RRB-': 0,
#                  '9_.': 0,
#                  '9_:': 0,
#                  '9_CC': 0,
#                  '9_CD': 0,
#                  '9_DT': 0,
#                  '9_EX': 0,
#                  '9_FW': 0,
#                  '9_IN': 0,
#                  '9_JJ': 0,
#                  '9_JJR': 0,
#                  '9_JJS': 0,
#                  '9_LS': 0,
#                  '9_MD': 0,
#                  '9_NN': 0,
#                  '9_NNP': 0,
#                  '9_NNPS': 0,
#                  '9_NNS': 0,
#                  '9_PDT': 0,
#                  '9_POS': 0,
#                  '9_PRP': 0,
#                  '9_PRP$': 0,
#                  '9_RB': 0,
#                  '9_RBR': 0,
#                  '9_RBS': 0,
#                  '9_RP': 0,
#                  '9_TO': 0,
#                  '9_UH': 0,
#                  '9_VB': 0,
#                  '9_VBD': 0,
#                  '9_VBG': 0,
#                  '9_VBN': 0,
#                  '9_VBP': 0,
#                  '9_VBZ': 0,
#                  '9_WDT': 0,
#                  '9_WP': 0,
#                  '9_WP$': 0,
#                  '9_WRB': 0,
#                  '9_``': 0},
#  'Natural': {"1_''": 0,
#              '1_,': 0,
#              '1_-LRB-': 0,
#              '1_-RRB-': 0,
#              '1_.': 0,
#              '1_:': 0,
#              '1_CC': 0,
#              '1_CD': 0,
#              '1_DT': 0,
#              '1_EX': 0,
#              '1_FW': 0,
#              '1_IN': 0,
#              '1_JJ': 0,
#              '1_JJR': 0,
#              '1_JJS': 0,
#              '1_LS': 0,
#              '1_MD': 0,
#              '1_NN': 0,
#              '1_NNP': 0,
#              '1_NNPS': 0,
#              '1_NNS': 0,
#              '1_PDT': 0,
#              '1_POS': 0,
#              '1_PRP': 0,
#              '1_PRP$': 0,
#              '1_RB': 0,
#              '1_RBR': 0,
#              '1_RBS': 0,
#              '1_RP': 0,
#              '1_TO': 0,
#              '1_UH': 0,
#              '1_VB': 0,
#              '1_VBD': 0,
#              '1_VBG': 0,
#              '1_VBN': 0,
#              '1_VBP': 0,
#              '1_VBZ': 0,
#              '1_WDT': 0,
#              '1_WP': 0,
#              '1_WP$': 0,
#              '1_WRB': 0,
#              '1_``': 0},
#  'ability': {"24_''": 0,
#              '24_,': 0,
#              '24_-LRB-': 0,
#              '24_-RRB-': 0,
#              '24_.': 0,
#              '24_:': 0,
#              '24_CC': 0,
#              '24_CD': 0,
#              '24_DT': 0,
#              '24_EX': 0,
#              '24_FW': 0,
#              '24_IN': 0,
#              '24_JJ': 0,
#              '24_JJR': 0,
#              '24_JJS': 0,
#              '24_LS': 0,
#              '24_MD': 0,
#              '24_NN': 0,
#              '24_NNP': 0,
#              '24_NNPS': 0,
#              '24_NNS': 0,
#              '24_PDT': 0,
#              '24_POS': 0,
#              '24_PRP': 0,
#              '24_PRP$': 0,
#              '24_RB': 0,
#              '24_RBR': 0,
#              '24_RBS': 0,
#              '24_RP': 0,
#              '24_TO': 0,
#              '24_UH': 0,
#              '24_VB': 0,
#              '24_VBD': 0,
#              '24_VBG': 0,
#              '24_VBN': 0,
#              '24_VBP': 0,
#              '24_VBZ': 0,
#              '24_WDT': 0,
#              '24_WP': 0,
#              '24_WP$': 0,
#              '24_WRB': 0,
#              '24_``': 0},
#  'about': {"18_''": 0,
#            '18_,': 0,
#            '18_-LRB-': 0,
#            '18_-RRB-': 0,
#            '18_.': 0,
#            '18_:': 0,
#            '18_CC': 0,
#            '18_CD': 0,
#            '18_DT': 0,
#            '18_EX': 0,
#            '18_FW': 0,
#            '18_IN': 0,
#            '18_JJ': 0,
#            '18_JJR': 0,
#            '18_JJS': 0,
#            '18_LS': 0,
#            '18_MD': 0,
#            '18_NN': 0,
#            '18_NNP': 0,
#            '18_NNPS': 0,
#            '18_NNS': 0,
#            '18_PDT': 0,
#            '18_POS': 0,
#            '18_PRP': 0,
#            '18_PRP$': 0,
#            '18_RB': 0,
#            '18_RBR': 0,
#            '18_RBS': 0,
#            '18_RP': 0,
#            '18_TO': 0,
#            '18_UH': 0,
#            '18_VB': 0,
#            '18_VBD': 0,
#            '18_VBG': 0,
#            '18_VBN': 0,
#            '18_VBP': 0,
#            '18_VBZ': 0,
#            '18_WDT': 0,
#            '18_WP': 0,
#            '18_WP$': 0,
#            '18_WRB': 0,
#            '18_``': 0},
#  'an': {"8_''": 0,
#         '8_,': 0,
#         '8_-LRB-': 0,
#         '8_-RRB-': 0,
#         '8_.': 0,
#         '8_:': 0,
#         '8_CC': 0,
#         '8_CD': 0,
#         '8_DT': 0,
#         '8_EX': 0,
#         '8_FW': 0,
#         '8_IN': 0,
#         '8_JJ': 0,
#         '8_JJR': 0,
#         '8_JJS': 0,
#         '8_LS': 0,
#         '8_MD': 0,
#         '8_NN': 0,
#         '8_NNP': 0,
#         '8_NNPS': 0,
#         '8_NNS': 0,
#         '8_PDT': 0,
#         '8_POS': 0,
#         '8_PRP': 0,
#         '8_PRP$': 0,
#         '8_RB': 0,
#         '8_RBR': 0,
#         '8_RBS': 0,
#         '8_RP': 0,
#         '8_TO': 0,
#         '8_UH': 0,
#         '8_VB': 0,
#         '8_VBD': 0,
#         '8_VBG': 0,
#         '8_VBN': 0,
#         '8_VBP': 0,
#         '8_VBZ': 0,
#         '8_WDT': 0,
#         '8_WP': 0,
#         '8_WP$': 0,
#         '8_WRB': 0,
#         '8_``': 0},
#  'and': {"22_''": 0,
#          '22_,': 0,
#          '22_-LRB-': 0,
#          '22_-RRB-': 0,
#          '22_.': 0,
#          '22_:': 0,
#          '22_CC': 0,
#          '22_CD': 0,
#          '22_DT': 0,
#          '22_EX': 0,
#          '22_FW': 0,
#          '22_IN': 0,
#          '22_JJ': 0,
#          '22_JJR': 0,
#          '22_JJS': 0,
#          '22_LS': 0,
#          '22_MD': 0,
#          '22_NN': 0,
#          '22_NNP': 0,
#          '22_NNPS': 0,
#          '22_NNS': 0,
#          '22_PDT': 0,
#          '22_POS': 0,
#          '22_PRP': 0,
#          '22_PRP$': 0,
#          '22_RB': 0,
#          '22_RBR': 0,
#          '22_RBS': 0,
#          '22_RP': 0,
#          '22_TO': 0,
#          '22_UH': 0,
#          '22_VB': 0,
#          '22_VBD': 0,
#          '22_VBG': 0,
#          '22_VBN': 0,
#          '22_VBP': 0,
#          '22_VBZ': 0,
#          '22_WDT': 0,
#          '22_WP': 0,
#          '22_WP$': 0,
#          '22_WRB': 0,
#          '22_``': 0},
#  'as': {"7_''": 0,
#         '7_,': 0,
#         '7_-LRB-': 0,
#         '7_-RRB-': 0,
#         '7_.': 0,
#         '7_:': 0,
#         '7_CC': 0,
#         '7_CD': 0,
#         '7_DT': 0,
#         '7_EX': 0,
#         '7_FW': 0,
#         '7_IN': 0,
#         '7_JJ': 0,
#         '7_JJR': 0,
#         '7_JJS': 0,
#         '7_LS': 0,
#         '7_MD': 0,
#         '7_NN': 0,
#         '7_NNP': 0,
#         '7_NNPS': 0,
#         '7_NNS': 0,
#         '7_PDT': 0,
#         '7_POS': 0,
#         '7_PRP': 0,
#         '7_PRP$': 0,
#         '7_RB': 0,
#         '7_RBR': 0,
#         '7_RBS': 0,
#         '7_RP': 0,
#         '7_TO': 0,
#         '7_UH': 0,
#         '7_VB': 0,
#         '7_VBD': 0,
#         '7_VBG': 0,
#         '7_VBN': 0,
#         '7_VBP': 0,
#         '7_VBZ': 0,
#         '7_WDT': 0,
#         '7_WP': 0,
#         '7_WP$': 0,
#         '7_WRB': 0,
#         '7_``': 0},
#  'because': {"11_''": 0,
#              '11_,': 0,
#              '11_-LRB-': 0,
#              '11_-RRB-': 0,
#              '11_.': 0,
#              '11_:': 0,
#              '11_CC': 0,
#              '11_CD': 0,
#              '11_DT': 0,
#              '11_EX': 0,
#              '11_FW': 0,
#              '11_IN': 0,
#              '11_JJ': 0,
#              '11_JJR': 0,
#              '11_JJS': 0,
#              '11_LS': 0,
#              '11_MD': 0,
#              '11_NN': 0,
#              '11_NNP': 0,
#              '11_NNPS': 0,
#              '11_NNS': 0,
#              '11_PDT': 0,
#              '11_POS': 0,
#              '11_PRP': 0,
#              '11_PRP$': 0,
#              '11_RB': 0,
#              '11_RBR': 0,
#              '11_RBS': 0,
#              '11_RP': 0,
#              '11_TO': 0,
#              '11_UH': 0,
#              '11_VB': 0,
#              '11_VBD': 0,
#              '11_VBG': 0,
#              '11_VBN': 0,
#              '11_VBP': 0,
#              '11_VBZ': 0,
#              '11_WDT': 0,
#              '11_WP': 0,
#              '11_WP$': 0,
#              '11_WRB': 0,
#              '11_``': 0},
#  'extensive': {"16_''": 0,
#                '16_,': 0,
#                '16_-LRB-': 0,
#                '16_-RRB-': 0,
#                '16_.': 0,
#                '16_:': 0,
#                '16_CC': 0,
#                '16_CD': 0,
#                '16_DT': 0,
#                '16_EX': 0,
#                '16_FW': 0,
#                '16_IN': 0,
#                '16_JJ': 0,
#                '16_JJR': 0,
#                '16_JJS': 0,
#                '16_LS': 0,
#                '16_MD': 0,
#                '16_NN': 0,
#                '16_NNP': 0,
#                '16_NNPS': 0,
#                '16_NNS': 0,
#                '16_PDT': 0,
#                '16_POS': 0,
#                '16_PRP': 0,
#                '16_PRP$': 0,
#                '16_RB': 0,
#                '16_RBR': 0,
#                '16_RBS': 0,
#                '16_RP': 0,
#                '16_TO': 0,
#                '16_UH': 0,
#                '16_VB': 0,
#                '16_VBD': 0,
#                '16_VBG': 0,
#                '16_VBN': 0,
#                '16_VBP': 0,
#                '16_VBZ': 0,
#                '16_WDT': 0,
#                '16_WP': 0,
#                '16_WP$': 0,
#                '16_WRB': 0,
#                '16_``': 0},
#  'is': {"4_''": 0,
#         '4_,': 0,
#         '4_-LRB-': 0,
#         '4_-RRB-': 0,
#         '4_.': 0,
#         '4_:': 0,
#         '4_CC': 0,
#         '4_CD': 0,
#         '4_DT': 0,
#         '4_EX': 0,
#         '4_FW': 0,
#         '4_IN': 0,
#         '4_JJ': 0,
#         '4_JJR': 0,
#         '4_JJS': 0,
#         '4_LS': 0,
#         '4_MD': 0,
#         '4_NN': 0,
#         '4_NNP': 0,
#         '4_NNPS': 0,
#         '4_NNS': 0,
#         '4_PDT': 0,
#         '4_POS': 0,
#         '4_PRP': 0,
#         '4_PRP$': 0,
#         '4_RB': 0,
#         '4_RBR': 0,
#         '4_RBS': 0,
#         '4_RP': 0,
#         '4_TO': 0,
#         '4_UH': 0,
#         '4_VB': 0,
#         '4_VBD': 0,
#         '4_VBG': 0,
#         '4_VBN': 0,
#         '4_VBP': 0,
#         '4_VBZ': 0,
#         '4_WDT': 0,
#         '4_WP': 0,
#         '4_WP$': 0,
#         '4_WRB': 0,
#         '4_``': 0},
#  'it': {"27_''": 0,
#         '27_,': 0,
#         '27_-LRB-': 0,
#         '27_-RRB-': 0,
#         '27_.': 0,
#         '27_:': 0,
#         '27_CC': 0,
#         '27_CD': 0,
#         '27_DT': 0,
#         '27_EX': 0,
#         '27_FW': 0,
#         '27_IN': 0,
#         '27_JJ': 0,
#         '27_JJR': 0,
#         '27_JJS': 0,
#         '27_LS': 0,
#         '27_MD': 0,
#         '27_NN': 0,
#         '27_NNP': 0,
#         '27_NNPS': 0,
#         '27_NNS': 0,
#         '27_PDT': 0,
#         '27_POS': 0,
#         '27_PRP': 0,
#         '27_PRP$': 0,
#         '27_RB': 0,
#         '27_RBR': 0,
#         '27_RBS': 0,
#         '27_RP': 0,
#         '27_TO': 0,
#         '27_UH': 0,
#         '27_VB': 0,
#         '27_VBD': 0,
#         '27_VBG': 0,
#         '27_VBN': 0,
#         '27_VBP': 0,
#         '27_VBZ': 0,
#         '27_WDT': 0,
#         '27_WP': 0,
#         '27_WP$': 0,
#         '27_WRB': 0,
#         '27_``': 0},
#  'knowledge': {"17_''": 0,
#                '17_,': 0,
#                '17_-LRB-': 0,
#                '17_-RRB-': 0,
#                '17_.': 0,
#                '17_:': 0,
#                '17_CC': 0,
#                '17_CD': 0,
#                '17_DT': 0,
#                '17_EX': 0,
#                '17_FW': 0,
#                '17_IN': 0,
#                '17_JJ': 0,
#                '17_JJR': 0,
#                '17_JJS': 0,
#                '17_LS': 0,
#                '17_MD': 0,
#                '17_NN': 0,
#                '17_NNP': 0,
#                '17_NNPS': 0,
#                '17_NNS': 0,
#                '17_PDT': 0,
#                '17_POS': 0,
#                '17_PRP': 0,
#                '17_PRP$': 0,
#                '17_RB': 0,
#                '17_RBR': 0,
#                '17_RBS': 0,
#                '17_RP': 0,
#                '17_TO': 0,
#                '17_UH': 0,
#                '17_VB': 0,
#                '17_VBD': 0,
#                '17_VBG': 0,
#                '17_VBN': 0,
#                '17_VBP': 0,
#                '17_VBZ': 0,
#                '17_WDT': 0,
#                '17_WP': 0,
#                '17_WP$': 0,
#                '17_WRB': 0,
#                '17_``': 0},
#  'language': {"2_''": 0,
#               '2_,': 0,
#               '2_-LRB-': 0,
#               '2_-RRB-': 0,
#               '2_.': 0,
#               '2_:': 0,
#               '2_CC': 0,
#               '2_CD': 0,
#               '2_DT': 0,
#               '2_EX': 0,
#               '2_FW': 0,
#               '2_IN': 0,
#               '2_JJ': 0,
#               '2_JJR': 0,
#               '2_JJS': 0,
#               '2_LS': 0,
#               '2_MD': 0,
#               '2_NN': 0,
#               '2_NNP': 0,
#               '2_NNPS': 0,
#               '2_NNS': 0,
#               '2_PDT': 0,
#               '2_POS': 0,
#               '2_PRP': 0,
#               '2_PRP$': 0,
#               '2_RB': 0,
#               '2_RBR': 0,
#               '2_RBS': 0,
#               '2_RP': 0,
#               '2_TO': 0,
#               '2_UH': 0,
#               '2_VB': 0,
#               '2_VBD': 0,
#               '2_VBG': 0,
#               '2_VBN': 0,
#               '2_VBP': 0,
#               '2_VBZ': 0,
#               '2_WDT': 0,
#               '2_WP': 0,
#               '2_WP$': 0,
#               '2_WRB': 0,
#               '2_``': 0},
#  'manipulate': {"26_''": 0,
#                 '26_,': 0,
#                 '26_-LRB-': 0,
#                 '26_-RRB-': 0,
#                 '26_.': 0,
#                 '26_:': 0,
#                 '26_CC': 0,
#                 '26_CD': 0,
#                 '26_DT': 0,
#                 '26_EX': 0,
#                 '26_FW': 0,
#                 '26_IN': 0,
#                 '26_JJ': 0,
#                 '26_JJR': 0,
#                 '26_JJS': 0,
#                 '26_LS': 0,
#                 '26_MD': 0,
#                 '26_NN': 0,
#                 '26_NNP': 0,
#                 '26_NNPS': 0,
#                 '26_NNS': 0,
#                 '26_PDT': 0,
#                 '26_POS': 0,
#                 '26_PRP': 0,
#                 '26_PRP$': 0,
#                 '26_RB': 0,
#                 '26_RBR': 0,
#                 '26_RBS': 0,
#                 '26_RP': 0,
#                 '26_TO': 0,
#                 '26_UH': 0,
#                 '26_VB': 0,
#                 '26_VBD': 0,
#                 '26_VBG': 0,
#                 '26_VBN': 0,
#                 '26_VBP': 0,
#                 '26_VBZ': 0,
#                 '26_WDT': 0,
#                 '26_WP': 0,
#                 '26_WP$': 0,
#                 '26_WRB': 0,
#                 '26_``': 0},
#  'outside': {"20_''": 0,
#              '20_,': 0,
#              '20_-LRB-': 0,
#              '20_-RRB-': 0,
#              '20_.': 0,
#              '20_:': 0,
#              '20_CC': 0,
#              '20_CD': 0,
#              '20_DT': 0,
#              '20_EX': 0,
#              '20_FW': 0,
#              '20_IN': 0,
#              '20_JJ': 0,
#              '20_JJR': 0,
#              '20_JJS': 0,
#              '20_LS': 0,
#              '20_MD': 0,
#              '20_NN': 0,
#              '20_NNP': 0,
#              '20_NNPS': 0,
#              '20_NNS': 0,
#              '20_PDT': 0,
#              '20_POS': 0,
#              '20_PRP': 0,
#              '20_PRP$': 0,
#              '20_RB': 0,
#              '20_RBR': 0,
#              '20_RBS': 0,
#              '20_RP': 0,
#              '20_TO': 0,
#              '20_UH': 0,
#              '20_VB': 0,
#              '20_VBD': 0,
#              '20_VBG': 0,
#              '20_VBN': 0,
#              '20_VBP': 0,
#              '20_VBZ': 0,
#              '20_WDT': 0,
#              '20_WP': 0,
#              '20_WP$': 0,
#              '20_WRB': 0,
#              '20_``': 0},
#  'problem': {"10_''": 0,
#              '10_,': 0,
#              '10_-LRB-': 0,
#              '10_-RRB-': 0,
#              '10_.': 0,
#              '10_:': 0,
#              '10_CC': 0,
#              '10_CD': 0,
#              '10_DT': 0,
#              '10_EX': 0,
#              '10_FW': 0,
#              '10_IN': 0,
#              '10_JJ': 0,
#              '10_JJR': 0,
#              '10_JJS': 0,
#              '10_LS': 0,
#              '10_MD': 0,
#              '10_NN': 0,
#              '10_NNP': 0,
#              '10_NNPS': 0,
#              '10_NNS': 0,
#              '10_PDT': 0,
#              '10_POS': 0,
#              '10_PRP': 0,
#              '10_PRP$': 0,
#              '10_RB': 0,
#              '10_RBR': 0,
#              '10_RBS': 0,
#              '10_RP': 0,
#              '10_TO': 0,
#              '10_UH': 0,
#              '10_VB': 0,
#              '10_VBD': 0,
#              '10_VBG': 0,
#              '10_VBN': 0,
#              '10_VBP': 0,
#              '10_VBZ': 0,
#              '10_WDT': 0,
#              '10_WP': 0,
#              '10_WP$': 0,
#              '10_WRB': 0,
#              '10_``': 0},
#  'referred': {"6_''": 0,
#               '6_,': 0,
#               '6_-LRB-': 0,
#               '6_-RRB-': 0,
#               '6_.': 0,
#               '6_:': 0,
#               '6_CC': 0,
#               '6_CD': 0,
#               '6_DT': 0,
#               '6_EX': 0,
#               '6_FW': 0,
#               '6_IN': 0,
#               '6_JJ': 0,
#               '6_JJR': 0,
#               '6_JJS': 0,
#               '6_LS': 0,
#               '6_MD': 0,
#               '6_NN': 0,
#               '6_NNP': 0,
#               '6_NNPS': 0,
#               '6_NNS': 0,
#               '6_PDT': 0,
#               '6_POS': 0,
#               '6_PRP': 0,
#               '6_PRP$': 0,
#               '6_RB': 0,
#               '6_RBR': 0,
#               '6_RBS': 0,
#               '6_RP': 0,
#               '6_TO': 0,
#               '6_UH': 0,
#               '6_VB': 0,
#               '6_VBD': 0,
#               '6_VBG': 0,
#               '6_VBN': 0,
#               '6_VBP': 0,
#               '6_VBZ': 0,
#               '6_WDT': 0,
#               '6_WP': 0,
#               '6_WP$': 0,
#               '6_WRB': 0,
#               '6_``': 0},
#  'require': {"15_''": 0,
#              '15_,': 0,
#              '15_-LRB-': 0,
#              '15_-RRB-': 0,
#              '15_.': 0,
#              '15_:': 0,
#              '15_CC': 0,
#              '15_CD': 0,
#              '15_DT': 0,
#              '15_EX': 0,
#              '15_FW': 0,
#              '15_IN': 0,
#              '15_JJ': 0,
#              '15_JJR': 0,
#              '15_JJS': 0,
#              '15_LS': 0,
#              '15_MD': 0,
#              '15_NN': 0,
#              '15_NNP': 0,
#              '15_NNPS': 0,
#              '15_NNS': 0,
#              '15_PDT': 0,
#              '15_POS': 0,
#              '15_PRP': 0,
#              '15_PRP$': 0,
#              '15_RB': 0,
#              '15_RBR': 0,
#              '15_RBS': 0,
#              '15_RP': 0,
#              '15_TO': 0,
#              '15_UH': 0,
#              '15_VB': 0,
#              '15_VBD': 0,
#              '15_VBG': 0,
#              '15_VBN': 0,
#              '15_VBP': 0,
#              '15_VBZ': 0,
#              '15_WDT': 0,
#              '15_WP': 0,
#              '15_WP$': 0,
#              '15_WRB': 0,
#              '15_``': 0},
#  'seems': {"13_''": 0,
#            '13_,': 0,
#            '13_-LRB-': 0,
#            '13_-RRB-': 0,
#            '13_.': 0,
#            '13_:': 0,
#            '13_CC': 0,
#            '13_CD': 0,
#            '13_DT': 0,
#            '13_EX': 0,
#            '13_FW': 0,
#            '13_IN': 0,
#            '13_JJ': 0,
#            '13_JJR': 0,
#            '13_JJS': 0,
#            '13_LS': 0,
#            '13_MD': 0,
#            '13_NN': 0,
#            '13_NNP': 0,
#            '13_NNPS': 0,
#            '13_NNS': 0,
#            '13_PDT': 0,
#            '13_POS': 0,
#            '13_PRP': 0,
#            '13_PRP$': 0,
#            '13_RB': 0,
#            '13_RBR': 0,
#            '13_RBS': 0,
#            '13_RP': 0,
#            '13_TO': 0,
#            '13_UH': 0,
#            '13_VB': 0,
#            '13_VBD': 0,
#            '13_VBG': 0,
#            '13_VBN': 0,
#            '13_VBP': 0,
#            '13_VBZ': 0,
#            '13_WDT': 0,
#            '13_WP': 0,
#            '13_WP$': 0,
#            '13_WRB': 0,
#            '13_``': 0},
#  'sometimes': {"5_''": 0,
#                '5_,': 0,
#                '5_-LRB-': 0,
#                '5_-RRB-': 0,
#                '5_.': 0,
#                '5_:': 0,
#                '5_CC': 0,
#                '5_CD': 0,
#                '5_DT': 0,
#                '5_EX': 0,
#                '5_FW': 0,
#                '5_IN': 0,
#                '5_JJ': 0,
#                '5_JJR': 0,
#                '5_JJS': 0,
#                '5_LS': 0,
#                '5_MD': 0,
#                '5_NN': 0,
#                '5_NNP': 0,
#                '5_NNPS': 0,
#                '5_NNS': 0,
#                '5_PDT': 0,
#                '5_POS': 0,
#                '5_PRP': 0,
#                '5_PRP$': 0,
#                '5_RB': 0,
#                '5_RBR': 0,
#                '5_RBS': 0,
#                '5_RP': 0,
#                '5_TO': 0,
#                '5_UH': 0,
#                '5_VB': 0,
#                '5_VBD': 0,
#                '5_VBG': 0,
#                '5_VBN': 0,
#                '5_VBP': 0,
#                '5_VBZ': 0,
#                '5_WDT': 0,
#                '5_WP': 0,
#                '5_WP$': 0,
#                '5_WRB': 0,
#                '5_``': 0},
#  'the': {"23_''": 0,
#          '23_,': 0,
#          '23_-LRB-': 0,
#          '23_-RRB-': 0,
#          '23_.': 0,
#          '23_:': 0,
#          '23_CC': 0,
#          '23_CD': 0,
#          '23_DT': 0,
#          '23_EX': 0,
#          '23_FW': 0,
#          '23_IN': 0,
#          '23_JJ': 0,
#          '23_JJR': 0,
#          '23_JJS': 0,
#          '23_LS': 0,
#          '23_MD': 0,
#          '23_NN': 0,
#          '23_NNP': 0,
#          '23_NNPS': 0,
#          '23_NNS': 0,
#          '23_PDT': 0,
#          '23_POS': 0,
#          '23_PRP': 0,
#          '23_PRP$': 0,
#          '23_RB': 0,
#          '23_RBR': 0,
#          '23_RBS': 0,
#          '23_RP': 0,
#          '23_TO': 0,
#          '23_UH': 0,
#          '23_VB': 0,
#          '23_VBD': 0,
#          '23_VBG': 0,
#          '23_VBN': 0,
#          '23_VBP': 0,
#          '23_VBZ': 0,
#          '23_WDT': 0,
#          '23_WP': 0,
#          '23_WP$': 0,
#          '23_WRB': 0,
#          '23_``': 0},
#  'to': {"25_''": 0,
#         '25_,': 0,
#         '25_-LRB-': 0,
#         '25_-RRB-': 0,
#         '25_.': 0,
#         '25_:': 0,
#         '25_CC': 0,
#         '25_CD': 0,
#         '25_DT': 0,
#         '25_EX': 0,
#         '25_FW': 0,
#         '25_IN': 0,
#         '25_JJ': 0,
#         '25_JJR': 0,
#         '25_JJS': 0,
#         '25_LS': 0,
#         '25_MD': 0,
#         '25_NN': 0,
#         '25_NNP': 0,
#         '25_NNPS': 0,
#         '25_NNS': 0,
#         '25_PDT': 0,
#         '25_POS': 0,
#         '25_PRP': 0,
#         '25_PRP$': 0,
#         '25_RB': 0,
#         '25_RBR': 0,
#         '25_RBS': 0,
#         '25_RP': 0,
#         '25_TO': 0,
#         '25_UH': 0,
#         '25_VB': 0,
#         '25_VBD': 0,
#         '25_VBG': 0,
#         '25_VBN': 0,
#         '25_VBP': 0,
#         '25_VBZ': 0,
#         '25_WDT': 0,
#         '25_WP': 0,
#         '25_WP$': 0,
#         '25_WRB': 0,
#         '25_``': 0},
#  'understanding': {"3_''": 0,
#                    '3_,': 0,
#                    '3_-LRB-': 0,
#                    '3_-RRB-': 0,
#                    '3_.': 0,
#                    '3_:': 0,
#                    '3_CC': 0,
#                    '3_CD': 0,
#                    '3_DT': 0,
#                    '3_EX': 0,
#                    '3_FW': 0,
#                    '3_IN': 0,
#                    '3_JJ': 0,
#                    '3_JJR': 0,
#                    '3_JJS': 0,
#                    '3_LS': 0,
#                    '3_MD': 0,
#                    '3_NN': 0,
#                    '3_NNP': 0,
#                    '3_NNPS': 0,
#                    '3_NNS': 0,
#                    '3_PDT': 0,
#                    '3_POS': 0,
#                    '3_PRP': 0,
#                    '3_PRP$': 0,
#                    '3_RB': 0,
#                    '3_RBR': 0,
#                    '3_RBS': 0,
#                    '3_RP': 0,
#                    '3_TO': 0,
#                    '3_UH': 0,
#                    '3_VB': 0,
#                    '3_VBD': 0,
#                    '3_VBG': 0,
#                    '3_VBN': 0,
#                    '3_VBP': 0,
#                    '3_VBZ': 0,
#                    '3_WDT': 0,
#                    '3_WP': 0,
#                    '3_WP$': 0,
#                    '3_WRB': 0,
#                    '3_``': 0},
#  'world': {"21_''": 0,
#            '21_,': 0,
#            '21_-LRB-': 0,
#            '21_-RRB-': 0,
#            '21_.': 0,
#            '21_:': 0,
#            '21_CC': 0,
#            '21_CD': 0,
#            '21_DT': 0,
#            '21_EX': 0,
#            '21_FW': 0,
#            '21_IN': 0,
#            '21_JJ': 0,
#            '21_JJR': 0,
#            '21_JJS': 0,
#            '21_LS': 0,
#            '21_MD': 0,
#            '21_NN': 0,
#            '21_NNP': 0,
#            '21_NNPS': 0,
#            '21_NNS': 0,
#            '21_PDT': 0,
#            '21_POS': 0,
#            '21_PRP': 0,
#            '21_PRP$': 0,
#            '21_RB': 0,
#            '21_RBR': 0,
#            '21_RBS': 0,
#            '21_RP': 0,
#            '21_TO': 0,
#            '21_UH': 0,
#            '21_VB': 0,
#            '21_VBD': 0,
#            '21_VBG': 0,
#            '21_VBN': 0,
#            '21_VBP': 0,
#            '21_VBZ': 0,
#            '21_WDT': 0,
#            '21_WP': 0,
#            '21_WP$': 0,
#            '21_WRB': 0,
#            '21_``': 0}}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-97-512ce64e6571> in <module>()
# ----> 1 temp.calc_POS_viterbi("Natural language understanding is sometimes referred as an AI-complete problem because it seems to require extensive knowledge about the outside world and the ability to manipulate it .")
#
# <ipython-input-94-39a9cab5ecf4> in calc_POS_viterbi(self, line_str)
#      76                     else:
#      77                         _ = -math.log(pos_trans_P) -math.log(pos_emiss_P)
# ---> 78                     if _ < best_score[w][str(n_) + "_" + tag]:
#      79                         best_score[w][str(n_) + "_" + tag] = _
#      80                         best_node[w][str(n_) + "_" + tag]=str(n_-1)+"_"+tag_prev
#
# KeyError: '12_JJ'
